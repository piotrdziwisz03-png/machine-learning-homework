# %%
import numpy as np

# %%
def vector_vector_multiplication(u,v):
    assert u.shape[0] == v.shape[0]

    n = u.shape[0]

    for i in range(n):
        result = result + u[i] * v[i]
    return result

# %%
U = np.array([
             [2,4,5,6],
             [1,2,1,2],
             [3,1,2,1]
])

# %%
v = np.array([
             [1,1,2],
             [0,0.5,1],
             [0,2,1],
             [2,1,0],
])

# %%
def matrix_vector_multiplication(U,v):
    assert U.shape[1] == v.shape[0]
    num_rows = U.shape[0]
    result = np.zeros(num_rows)
    for i in range(num_rows):
        result[i] = vector_vector_multiplication(U[i], v)
    return result

# %%
matrix_vector_multiplication(U, v)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 matrix_vector_multiplication(U, v)
#
# Cell In[33], line 6, in matrix_vector_multiplication(U, v)
#       4 result = np.zeros(num_rows)
#       5 for i in range(num_rows):
# ----> 6     result[i] = vector_vector_multiplication(U[i], v)
#       7 return result
#
# Cell In[8], line 7, in vector_vector_multiplication(u, v)
#       4 n = u.shape[0]
#       6 for i in range(n):
# ----> 7     result = result + u[i] * v[i]
#       8 return result
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value
